# %% [markdown]
# # 04. Agents, Function Calling, Text-to-SQL, MCP (개념/의사코드)

# %%
schema = {"name":"get_weather","parameters":{"type":"object","properties":{"city":{"type":"string"}}}}
def get_weather(city):
    return {"city": city, "temp": 26, "desc": "cloudy"}

# %%
schema = {"tables":["faq"], "columns":{"faq":["question","answer"]}}
q = "신청 절차를 알려줘"
sql = "SELECT answer FROM faq WHERE question LIKE '%신청 절차%';"
print('SQL:', sql)
